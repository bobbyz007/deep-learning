# %% [markdown]
# # 不用pytorch的dataloader版本的卷积神经网络
#
# 1. 首先，我们需要学习PyTorch自带的数据加载器，包括dataset，sampler，以及data loader这三个对象组成的套件。
#
# 2. 当数据集很小，格式比较规则的时候，数据加载三套件的优势并不明显。但是当数据格式比较特殊，以及数据规模很大（内存无法同时加载所有数据）
# 的时候，特别是，我们需要用不同的处理器来加载数据的时候，三套件的威力就会显现出来了。它会将数据加载、分布的任务自动完成。
#
# 3. 在使用的时候，我们用dataset来装载数据集，用sampler来采样数据集。而对数据集的迭代、循环则主要通过data_loader来完成。

# %%
# 不用pytorch的dataloader版本的卷积神经网络

import gzip
import os
import sys

from six.moves import urllib

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import matplotlib.pyplot as plt
import numpy as np

#定义一系列常数
SOURCE_URL = 'http://yann.lecun.com/exdb/mnist/' #图像数据如果没下载，可以从这个地址下载
WORK_DIRECTORY = '5_convolution_data_raw' #存储的路径名
IMAGE_SIZE = 28 #每张图片的大小尺寸
NUM_CHANNELS = 1  #每张图片的通道数
PIXEL_DEPTH = 255 #像素的深度0-255
NUM_LABELS = 10 #手写数字，一共十种
VALIDATION_SIZE = 5000 #校验数据集大小
NUM_EPOCHS = 20 # 训练的循环周期
BATCH_SIZE = 64 #batch的大小
EVAL_FREQUENCY = 100 #每隔100个batch进行一次校验集计算

# %%
#下载图像文件，如果文件已经存在，那么就不下载。
def maybe_download(filename):
    """Download the data from Yann's website, unless it's already here."""
    if not os.path.isdir(WORK_DIRECTORY):
        os.mkdir(WORK_DIRECTORY)
    filepath = os.path.join(WORK_DIRECTORY, filename)
    print(filepath)
    if not os.path.exists(filepath):
        filepath, _ = urllib.request.urlretrieve(SOURCE_URL + filename, filepath)
        size = os.path.getsize(filepath)
        print('Successfully downloaded', filename, size, 'bytes.')
    return filepath
# Get the data.
train_data_filename = maybe_download('train-images-idx3-ubyte.gz')
train_labels_filename = maybe_download('train-labels-idx1-ubyte.gz')
test_data_filename = maybe_download('t10k-images-idx3-ubyte.gz')
test_labels_filename = maybe_download('t10k-labels-idx1-ubyte.gz')
# Out:
# 5_convolution_data_raw/train-images-idx3-ubyte.gz
# 5_convolution_data_raw/train-labels-idx1-ubyte.gz
# 5_convolution_data_raw/t10k-images-idx3-ubyte.gz
# 5_convolution_data_raw/t10k-labels-idx1-ubyte.gz

# %%
def extract_data(filename, num_images):
    # filename: 文件存放的路径，num_images: 读入的图片个数
    """将图像解压缩展开，读入成一个4维的张量： [image index（图像的编码）, y（纵坐标）, x（横坐标）, channels（通道）].
    我们将数组中的数值范围从原来的[0, 255]降低到了[-0.5, 0.5]范围内
    """
    print('Extracting', filename)
    with gzip.open(filename) as bytestream:
        bytestream.read(16) # 前16个字节分别存放magic number,number of images,number of rows,number of columns
        buf = bytestream.read(IMAGE_SIZE * IMAGE_SIZE * num_images * NUM_CHANNELS)
        data = np.frombuffer(buf, dtype=np.uint8).astype(np.float32)
        data = (data - (PIXEL_DEPTH / 2.0)) / PIXEL_DEPTH  # 压缩像素值
        data = data.reshape(num_images, NUM_CHANNELS, IMAGE_SIZE, IMAGE_SIZE)
        return data

def extract_labels(filename, num_images):
    """将label的数据文件解压缩，并将label读成64位的整数"""
    print('Extracting', filename)
    with gzip.open(filename) as bytestream:
        bytestream.read(8) # 前8个字节分别存放magic number， number of items
        buf = bytestream.read(1 * num_images)
        labels = np.frombuffer(buf, dtype=np.uint8).astype(np.int64)
    return labels

# 将数据解压缩并存储到数组中，60000张图片，60000个label，测试集中有10000张图片
train_data = extract_data(train_data_filename, 60000)
train_labels = extract_labels(train_labels_filename, 60000)
test_data = extract_data(test_data_filename, 10000)
test_labels = extract_labels(test_labels_filename, 10000)

# 将一部分图片（VALIDATION_SIZE=5000张）定为校验数据集
validation_data = train_data[:VALIDATION_SIZE, ...]
validation_labels = train_labels[:VALIDATION_SIZE]
train_data = train_data[VALIDATION_SIZE:, ...]
train_labels = train_labels[VALIDATION_SIZE:]
num_epochs = NUM_EPOCHS
# Out:
# Extracting 5_convolution_data_raw/train-images-idx3-ubyte.gz
# Extracting 5_convolution_data_raw/train-labels-idx1-ubyte.gz
# Extracting 5_convolution_data_raw/t10k-images-idx3-ubyte.gz
# Extracting 5_convolution_data_raw/t10k-labels-idx1-ubyte.gz

# %%
#随便从数据集中读入一张图片，并绘制出来
idx = 100
muteimg = train_data[idx, 0, :, :]
plt.imshow(muteimg)

# %%
# 定义关键函数

def error_rate(predictions, labels):
    """计算预测错误率的函数，其中predictions是模型给出的一组预测结果，labels是数据之中的正确答案"""
    predictions = np.argmax(predictions, 1)
    return 100.0 - (
      100.0 *
      np.sum( predictions == labels) /
      predictions.shape[0])

def eval_in_batches(data, net):
    """计算得到预测精度，运行对所有的数据集中的小撮数据进行."""
    size = data.shape[0]
    if size < BATCH_SIZE:
        raise ValueError("batch size for evals larger than dataset: %d" % size)
    predictions = np.ndarray(shape=(size, NUM_LABELS), dtype=np.float32)
    
    #一个小撮一个小撮地进行预测的计算
    for begin in range(0, size, BATCH_SIZE):
        end = begin + BATCH_SIZE
        if end <= size:
            inputs = data[begin:end]
            inputs = torch.from_numpy(inputs)
            inputs = inputs.clone().detach().requires_grad_(True)
            outputs = net(inputs)
            predictions[begin:end, :] = outputs.data.numpy()
        else:
            inputs = data[-BATCH_SIZE:]
            inputs = torch.from_numpy(inputs)
            inputs = inputs.clone().detach().requires_grad_(True)
            outputs = net(inputs)
            
            batch_predictions = outputs.data.numpy()
            predictions[begin:, :] = batch_predictions[begin - size:, :]
    return predictions

# %%
# 构建卷积神经网络
depth = [4, 8] # 卷积层的厚度

class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()  # 调用父类构造函数

        # 卷积后图像维度不变， size + padding * 2 - kernel_size + 1 = size + 4 - 5 + 1 = size
        self.conv1 = nn.Conv2d(in_channels = 1, out_channels = 4, kernel_size = 5, padding = 2) # 卷积层
        
        self.pool = nn.MaxPool2d(2, 2) #  池化层
        
        self.conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) # 第二层卷积

        self.fc1 = nn.Linear(IMAGE_SIZE // 4 * IMAGE_SIZE // 4 * depth[1], 512) 
        self.fc2 = nn.Linear(512, NUM_LABELS)
        
    def forward(self, x):
        # 神经网络完成真正的前向运算，拼装各个实际的组件
        x = self.conv1(x) # 第一层卷积
        x = F.relu(x)  # (batch_size, num_filters, image_width, image_height]

        x = self.pool(x) # 第二层池化，图片变小：(batch_size, num_filters, image_width / 2, image_height / 2]

        x = self.conv2(x) #第三层卷积, (batch_size, depth[1], image_width / 2, image_height / 2]
        x = F.relu(x)  

        x = self.pool(x) #第四层池化， 图片缩小 (batch_size, depth[1], image_width / 2 / 2, image_height / 2 / 2]

        x = x.view(-1, IMAGE_SIZE // 4 * IMAGE_SIZE // 4 * depth[1])  # 压缩向量

        x = F.relu(self.fc1(x)) # 第五层为全连接  (batch_size, 512)

        x = F.dropout(x, training = self.training) # 默认以0.5的概率对这一层进行dropout操作，防止过拟合
        x = self.fc2(x)  # 全连接层，最终输出 （batch_size, num_classes）

        x = F.log_softmax(x, dim=1)
        return x

    def retrieve_features(self, x):
        # 返回前两层卷积层的特征图
        feature_map1 = F.relu(self.conv1(x))
        x = self.pool(feature_map1)

        feature_map2 = F.relu(self.conv2(x))
        return (feature_map1, feature_map2)

# %%
error_rate_rec = []

#获得训练集尺寸
train_size = train_labels.shape[0]

print('Initialized!')

net = ConvNet()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# 开始训练循环，一共进行int(num_epochs * train_size) // BATCH_SIZE次
print('Total loops: {}, Epoch: {}\n'.format(int(num_epochs * train_size) // BATCH_SIZE, NUM_EPOCHS))
for step in range(int(num_epochs * train_size) // BATCH_SIZE):
    # 计算当前应该访问训练集中的哪一部分数据
    # Note that we could use better randomization across epochs.
    offset = (step * BATCH_SIZE) % (train_size - BATCH_SIZE)
    batch_data = train_data[offset:(offset + BATCH_SIZE), ...]
    batch_labels = train_labels[offset:(offset + BATCH_SIZE)]
    batch_data = torch.from_numpy(batch_data)
    batch_labels = torch.from_numpy(batch_labels)
    
    inputs, labels = batch_data.clone().detach(), batch_labels.clone().detach()
    
    
    # zero the parameter gradients
    optimizer.zero_grad()

    # forward + backward + optimize
    outputs = net(inputs)
    loss = criterion(outputs, labels)
    #print(loss)
    loss.backward()
    optimizer.step()
    
    if step % EVAL_FREQUENCY == 0:
        #每间隔EVAL_FREQUENCY就打印一次预测结果

        #print('损失函数值: %.3f, 学习率: %.6f' % (l, lr))
        predictions = outputs.data.numpy()
        #print(predictions.shape)
        err_train = error_rate(predictions, labels.data.numpy())
        prediction = eval_in_batches(validation_data, net)
        err_valid = error_rate(prediction, validation_labels)

        print('第 {} (epoch: {:.2f}) 步:\t 训练集测试率: {:.2f}%,\t校验集测试率: {:.2f}%'.format(
            step, float(step) * BATCH_SIZE / train_size, 
            err_train, err_valid
        ))

        error_rate_rec.append([err_train,err_valid])
        sys.stdout.flush()
# 在测试集上实验
prediction = eval_in_batches(test_data, net)
test_error = error_rate(prediction, test_labels)
print('测试误差: %.1f%%' % test_error)
# Out:
# Initialized!
# Total loops: 17187, Epoch: 20
#
# 第 0 (epoch: 0.00) 步:	 训练测试率: 95.31%,	校验集测试率: 89.08%
# 第 100 (epoch: 0.12) 步:	 训练测试率: 89.06%,	校验集测试率: 87.92%
# 第 200 (epoch: 0.23) 步:	 训练测试率: 87.50%,	校验集测试率: 85.56%
# 第 300 (epoch: 0.35) 步:	 训练测试率: 85.94%,	校验集测试率: 82.62%
# 第 400 (epoch: 0.47) 步:	 训练测试率: 79.69%,	校验集测试率: 76.96%
# 第 500 (epoch: 0.58) 步:	 训练测试率: 56.25%,	校验集测试率: 70.28%
# 第 600 (epoch: 0.70) 步:	 训练测试率: 60.94%,	校验集测试率: 64.10%
# 第 700 (epoch: 0.81) 步:	 训练测试率: 67.19%,	校验集测试率: 62.66%
# 第 800 (epoch: 0.93) 步:	 训练测试率: 45.31%,	校验集测试率: 48.06%
# 第 900 (epoch: 1.05) 步:	 训练测试率: 28.12%,	校验集测试率: 27.64%
# 第 1000 (epoch: 1.16) 步:	 训练测试率: 28.12%,	校验集测试率: 20.66%
# 第 1100 (epoch: 1.28) 步:	 训练测试率: 4.69%,	校验集测试率: 17.36%
# 第 1200 (epoch: 1.40) 步:	 训练测试率: 10.94%,	校验集测试率: 14.10%
# 第 1300 (epoch: 1.51) 步:	 训练测试率: 3.12%,	校验集测试率: 12.68%
# 第 1400 (epoch: 1.63) 步:	 训练测试率: 10.94%,	校验集测试率: 11.00%
# 第 1500 (epoch: 1.75) 步:	 训练测试率: 10.94%,	校验集测试率: 10.52%
# 第 1600 (epoch: 1.86) 步:	 训练测试率: 7.81%,	校验集测试率: 9.40%
# 第 1700 (epoch: 1.98) 步:	 训练测试率: 4.69%,	校验集测试率: 9.14%
# 第 1800 (epoch: 2.09) 步:	 训练测试率: 1.56%,	校验集测试率: 9.32%
# 第 1900 (epoch: 2.21) 步:	 训练测试率: 9.38%,	校验集测试率: 8.26%
# 第 2000 (epoch: 2.33) 步:	 训练测试率: 7.81%,	校验集测试率: 8.48%
# 第 2100 (epoch: 2.44) 步:	 训练测试率: 9.38%,	校验集测试率: 8.00%
# 第 2200 (epoch: 2.56) 步:	 训练测试率: 7.81%,	校验集测试率: 7.62%
# 第 2300 (epoch: 2.68) 步:	 训练测试率: 9.38%,	校验集测试率: 7.50%
# 第 2400 (epoch: 2.79) 步:	 训练测试率: 3.12%,	校验集测试率: 7.04%
# 第 2500 (epoch: 2.91) 步:	 训练测试率: 7.81%,	校验集测试率: 6.56%
# 第 2600 (epoch: 3.03) 步:	 训练测试率: 3.12%,	校验集测试率: 7.16%
# 第 2700 (epoch: 3.14) 步:	 训练测试率: 12.50%,	校验集测试率: 6.94%
# 第 2800 (epoch: 3.26) 步:	 训练测试率: 7.81%,	校验集测试率: 6.08%
# 第 2900 (epoch: 3.37) 步:	 训练测试率: 7.81%,	校验集测试率: 6.16%
# 第 3000 (epoch: 3.49) 步:	 训练测试率: 1.56%,	校验集测试率: 6.32%
# 第 3100 (epoch: 3.61) 步:	 训练测试率: 6.25%,	校验集测试率: 6.04%
# 第 3200 (epoch: 3.72) 步:	 训练测试率: 12.50%,	校验集测试率: 5.94%
# 第 3300 (epoch: 3.84) 步:	 训练测试率: 1.56%,	校验集测试率: 5.56%
# 第 3400 (epoch: 3.96) 步:	 训练测试率: 3.12%,	校验集测试率: 6.08%
# 第 3500 (epoch: 4.07) 步:	 训练测试率: 4.69%,	校验集测试率: 5.52%
# 第 3600 (epoch: 4.19) 步:	 训练测试率: 1.56%,	校验集测试率: 5.30%
# 第 3700 (epoch: 4.31) 步:	 训练测试率: 3.12%,	校验集测试率: 5.06%
# 第 3800 (epoch: 4.42) 步:	 训练测试率: 4.69%,	校验集测试率: 5.12%
# 第 3900 (epoch: 4.54) 步:	 训练测试率: 4.69%,	校验集测试率: 4.94%
# 第 4000 (epoch: 4.65) 步:	 训练测试率: 7.81%,	校验集测试率: 5.34%
# 第 4100 (epoch: 4.77) 步:	 训练测试率: 1.56%,	校验集测试率: 4.96%
# 第 4200 (epoch: 4.89) 步:	 训练测试率: 4.69%,	校验集测试率: 4.58%
# 第 4300 (epoch: 5.00) 步:	 训练测试率: 6.25%,	校验集测试率: 4.96%
# 第 4400 (epoch: 5.12) 步:	 训练测试率: 3.12%,	校验集测试率: 4.80%
# 第 4500 (epoch: 5.24) 步:	 训练测试率: 6.25%,	校验集测试率: 4.62%
# 第 4600 (epoch: 5.35) 步:	 训练测试率: 7.81%,	校验集测试率: 4.34%
# 第 4700 (epoch: 5.47) 步:	 训练测试率: 1.56%,	校验集测试率: 4.28%
# 第 4800 (epoch: 5.59) 步:	 训练测试率: 7.81%,	校验集测试率: 3.96%
# 第 4900 (epoch: 5.70) 步:	 训练测试率: 6.25%,	校验集测试率: 4.22%
# 第 5000 (epoch: 5.82) 步:	 训练测试率: 10.94%,	校验集测试率: 4.12%
# 第 5100 (epoch: 5.93) 步:	 训练测试率: 4.69%,	校验集测试率: 4.18%
# 第 5200 (epoch: 6.05) 步:	 训练测试率: 6.25%,	校验集测试率: 4.28%
# 第 5300 (epoch: 6.17) 步:	 训练测试率: 7.81%,	校验集测试率: 3.82%
# 第 5400 (epoch: 6.28) 步:	 训练测试率: 6.25%,	校验集测试率: 4.06%
# 第 5500 (epoch: 6.40) 步:	 训练测试率: 4.69%,	校验集测试率: 3.70%
# 第 5600 (epoch: 6.52) 步:	 训练测试率: 4.69%,	校验集测试率: 3.72%
# 第 5700 (epoch: 6.63) 步:	 训练测试率: 4.69%,	校验集测试率: 3.98%
# 第 5800 (epoch: 6.75) 步:	 训练测试率: 4.69%,	校验集测试率: 3.52%
# 第 5900 (epoch: 6.87) 步:	 训练测试率: 4.69%,	校验集测试率: 4.02%
# 第 6000 (epoch: 6.98) 步:	 训练测试率: 7.81%,	校验集测试率: 3.90%
# 第 6100 (epoch: 7.10) 步:	 训练测试率: 4.69%,	校验集测试率: 3.44%
# 第 6200 (epoch: 7.21) 步:	 训练测试率: 1.56%,	校验集测试率: 3.42%
# 第 6300 (epoch: 7.33) 步:	 训练测试率: 1.56%,	校验集测试率: 3.34%
# 第 6400 (epoch: 7.45) 步:	 训练测试率: 3.12%,	校验集测试率: 3.86%
# 第 6500 (epoch: 7.56) 步:	 训练测试率: 1.56%,	校验集测试率: 3.68%
# 第 6600 (epoch: 7.68) 步:	 训练测试率: 4.69%,	校验集测试率: 3.42%
# 第 6700 (epoch: 7.80) 步:	 训练测试率: 4.69%,	校验集测试率: 3.50%
# 第 6800 (epoch: 7.91) 步:	 训练测试率: 1.56%,	校验集测试率: 3.52%
# 第 6900 (epoch: 8.03) 步:	 训练测试率: 4.69%,	校验集测试率: 3.16%
# 第 7000 (epoch: 8.15) 步:	 训练测试率: 1.56%,	校验集测试率: 3.72%
# 第 7100 (epoch: 8.26) 步:	 训练测试率: 3.12%,	校验集测试率: 3.64%
# 第 7200 (epoch: 8.38) 步:	 训练测试率: 1.56%,	校验集测试率: 3.16%
# 第 7300 (epoch: 8.49) 步:	 训练测试率: 1.56%,	校验集测试率: 3.28%
# 第 7400 (epoch: 8.61) 步:	 训练测试率: 3.12%,	校验集测试率: 3.36%
# 第 7500 (epoch: 8.73) 步:	 训练测试率: 4.69%,	校验集测试率: 3.22%
# 第 7600 (epoch: 8.84) 步:	 训练测试率: 1.56%,	校验集测试率: 3.46%
# 第 7700 (epoch: 8.96) 步:	 训练测试率: 1.56%,	校验集测试率: 3.30%
# 第 7800 (epoch: 9.08) 步:	 训练测试率: 3.12%,	校验集测试率: 3.08%
# 第 7900 (epoch: 9.19) 步:	 训练测试率: 4.69%,	校验集测试率: 3.14%
# 第 8000 (epoch: 9.31) 步:	 训练测试率: 6.25%,	校验集测试率: 3.44%
# 第 8100 (epoch: 9.43) 步:	 训练测试率: 1.56%,	校验集测试率: 2.82%
# 第 8200 (epoch: 9.54) 步:	 训练测试率: 4.69%,	校验集测试率: 2.86%
# 第 8300 (epoch: 9.66) 步:	 训练测试率: 6.25%,	校验集测试率: 3.18%
# 第 8400 (epoch: 9.77) 步:	 训练测试率: 0.00%,	校验集测试率: 3.14%
# 第 8500 (epoch: 9.89) 步:	 训练测试率: 1.56%,	校验集测试率: 3.08%
# 第 8600 (epoch: 10.01) 步:	 训练测试率: 4.69%,	校验集测试率: 3.20%
# 第 8700 (epoch: 10.12) 步:	 训练测试率: 1.56%,	校验集测试率: 3.80%
# 第 8800 (epoch: 10.24) 步:	 训练测试率: 1.56%,	校验集测试率: 2.96%
# 第 8900 (epoch: 10.36) 步:	 训练测试率: 4.69%,	校验集测试率: 3.00%
# 第 9000 (epoch: 10.47) 步:	 训练测试率: 6.25%,	校验集测试率: 2.88%
# 第 9100 (epoch: 10.59) 步:	 训练测试率: 1.56%,	校验集测试率: 2.74%
# 第 9200 (epoch: 10.71) 步:	 训练测试率: 4.69%,	校验集测试率: 3.20%
# 第 9300 (epoch: 10.82) 步:	 训练测试率: 6.25%,	校验集测试率: 3.08%
# 第 9400 (epoch: 10.94) 步:	 训练测试率: 3.12%,	校验集测试率: 2.78%
# 第 9500 (epoch: 11.05) 步:	 训练测试率: 9.38%,	校验集测试率: 3.04%
# 第 9600 (epoch: 11.17) 步:	 训练测试率: 6.25%,	校验集测试率: 2.36%
# 第 9700 (epoch: 11.29) 步:	 训练测试率: 1.56%,	校验集测试率: 2.92%
# 第 9800 (epoch: 11.40) 步:	 训练测试率: 4.69%,	校验集测试率: 2.84%
# 第 9900 (epoch: 11.52) 步:	 训练测试率: 1.56%,	校验集测试率: 2.84%
# 第 10000 (epoch: 11.64) 步:	 训练测试率: 1.56%,	校验集测试率: 2.98%
# 第 10100 (epoch: 11.75) 步:	 训练测试率: 4.69%,	校验集测试率: 2.70%
# 第 10200 (epoch: 11.87) 步:	 训练测试率: 3.12%,	校验集测试率: 2.70%
# 第 10300 (epoch: 11.99) 步:	 训练测试率: 1.56%,	校验集测试率: 2.78%
# 第 10400 (epoch: 12.10) 步:	 训练测试率: 0.00%,	校验集测试率: 2.68%
# 第 10500 (epoch: 12.22) 步:	 训练测试率: 1.56%,	校验集测试率: 3.06%
# 第 10600 (epoch: 12.33) 步:	 训练测试率: 4.69%,	校验集测试率: 2.40%
# 第 10700 (epoch: 12.45) 步:	 训练测试率: 1.56%,	校验集测试率: 2.72%
# 第 10800 (epoch: 12.57) 步:	 训练测试率: 1.56%,	校验集测试率: 2.46%
# 第 10900 (epoch: 12.68) 步:	 训练测试率: 0.00%,	校验集测试率: 2.52%
# 第 11000 (epoch: 12.80) 步:	 训练测试率: 1.56%,	校验集测试率: 2.38%
# 第 11100 (epoch: 12.92) 步:	 训练测试率: 3.12%,	校验集测试率: 2.74%
# 第 11200 (epoch: 13.03) 步:	 训练测试率: 0.00%,	校验集测试率: 2.86%
# 第 11300 (epoch: 13.15) 步:	 训练测试率: 1.56%,	校验集测试率: 2.40%
# 第 11400 (epoch: 13.27) 步:	 训练测试率: 1.56%,	校验集测试率: 2.54%
# 第 11500 (epoch: 13.38) 步:	 训练测试率: 4.69%,	校验集测试率: 2.56%
# 第 11600 (epoch: 13.50) 步:	 训练测试率: 4.69%,	校验集测试率: 2.50%
# 第 11700 (epoch: 13.61) 步:	 训练测试率: 6.25%,	校验集测试率: 2.64%
# 第 11800 (epoch: 13.73) 步:	 训练测试率: 3.12%,	校验集测试率: 2.80%
# 第 11900 (epoch: 13.85) 步:	 训练测试率: 3.12%,	校验集测试率: 2.50%
# 第 12000 (epoch: 13.96) 步:	 训练测试率: 4.69%,	校验集测试率: 2.34%
# 第 12100 (epoch: 14.08) 步:	 训练测试率: 3.12%,	校验集测试率: 2.50%
# 第 12200 (epoch: 14.20) 步:	 训练测试率: 6.25%,	校验集测试率: 2.38%
# 第 12300 (epoch: 14.31) 步:	 训练测试率: 1.56%,	校验集测试率: 2.58%
# 第 12400 (epoch: 14.43) 步:	 训练测试率: 1.56%,	校验集测试率: 2.70%
# 第 12500 (epoch: 14.55) 步:	 训练测试率: 3.12%,	校验集测试率: 2.50%
# 第 12600 (epoch: 14.66) 步:	 训练测试率: 1.56%,	校验集测试率: 2.26%
# 第 12700 (epoch: 14.78) 步:	 训练测试率: 1.56%,	校验集测试率: 2.40%
# 第 12800 (epoch: 14.89) 步:	 训练测试率: 0.00%,	校验集测试率: 2.52%
# 第 12900 (epoch: 15.01) 步:	 训练测试率: 3.12%,	校验集测试率: 2.52%
# 第 13000 (epoch: 15.13) 步:	 训练测试率: 1.56%,	校验集测试率: 2.28%
# 第 13100 (epoch: 15.24) 步:	 训练测试率: 3.12%,	校验集测试率: 2.38%
# 第 13200 (epoch: 15.36) 步:	 训练测试率: 4.69%,	校验集测试率: 2.62%
# 第 13300 (epoch: 15.48) 步:	 训练测试率: 0.00%,	校验集测试率: 2.22%
# 第 13400 (epoch: 15.59) 步:	 训练测试率: 3.12%,	校验集测试率: 2.32%
# 第 13500 (epoch: 15.71) 步:	 训练测试率: 4.69%,	校验集测试率: 2.40%
# 第 13600 (epoch: 15.83) 步:	 训练测试率: 1.56%,	校验集测试率: 2.00%
# 第 13700 (epoch: 15.94) 步:	 训练测试率: 1.56%,	校验集测试率: 2.46%
# 第 13800 (epoch: 16.06) 步:	 训练测试率: 0.00%,	校验集测试率: 2.42%
# 第 13900 (epoch: 16.17) 步:	 训练测试率: 0.00%,	校验集测试率: 2.28%
# 第 14000 (epoch: 16.29) 步:	 训练测试率: 1.56%,	校验集测试率: 2.22%
# 第 14100 (epoch: 16.41) 步:	 训练测试率: 0.00%,	校验集测试率: 2.12%
# 第 14200 (epoch: 16.52) 步:	 训练测试率: 3.12%,	校验集测试率: 2.36%
# 第 14300 (epoch: 16.64) 步:	 训练测试率: 4.69%,	校验集测试率: 2.26%
# 第 14400 (epoch: 16.76) 步:	 训练测试率: 0.00%,	校验集测试率: 2.16%
# 第 14500 (epoch: 16.87) 步:	 训练测试率: 1.56%,	校验集测试率: 2.20%
# 第 14600 (epoch: 16.99) 步:	 训练测试率: 0.00%,	校验集测试率: 2.18%
# 第 14700 (epoch: 17.11) 步:	 训练测试率: 3.12%,	校验集测试率: 2.26%
# 第 14800 (epoch: 17.22) 步:	 训练测试率: 3.12%,	校验集测试率: 2.16%
# 第 14900 (epoch: 17.34) 步:	 训练测试率: 1.56%,	校验集测试率: 2.24%
# 第 15000 (epoch: 17.45) 步:	 训练测试率: 1.56%,	校验集测试率: 2.28%
# 第 15100 (epoch: 17.57) 步:	 训练测试率: 1.56%,	校验集测试率: 2.34%
# 第 15200 (epoch: 17.69) 步:	 训练测试率: 3.12%,	校验集测试率: 2.70%
# 第 15300 (epoch: 17.80) 步:	 训练测试率: 3.12%,	校验集测试率: 2.20%
# 第 15400 (epoch: 17.92) 步:	 训练测试率: 0.00%,	校验集测试率: 2.44%
# 第 15500 (epoch: 18.04) 步:	 训练测试率: 4.69%,	校验集测试率: 2.06%
# 第 15600 (epoch: 18.15) 步:	 训练测试率: 3.12%,	校验集测试率: 2.10%
# 第 15700 (epoch: 18.27) 步:	 训练测试率: 6.25%,	校验集测试率: 2.00%
# 第 15800 (epoch: 18.39) 步:	 训练测试率: 0.00%,	校验集测试率: 2.36%
# 第 15900 (epoch: 18.50) 步:	 训练测试率: 4.69%,	校验集测试率: 2.38%
# 第 16000 (epoch: 18.62) 步:	 训练测试率: 0.00%,	校验集测试率: 2.10%
# 第 16100 (epoch: 18.73) 步:	 训练测试率: 0.00%,	校验集测试率: 2.10%
# 第 16200 (epoch: 18.85) 步:	 训练测试率: 4.69%,	校验集测试率: 2.28%
# 第 16300 (epoch: 18.97) 步:	 训练测试率: 3.12%,	校验集测试率: 2.08%
# 第 16400 (epoch: 19.08) 步:	 训练测试率: 0.00%,	校验集测试率: 2.30%
# 第 16500 (epoch: 19.20) 步:	 训练测试率: 1.56%,	校验集测试率: 2.10%
# 第 16600 (epoch: 19.32) 步:	 训练测试率: 3.12%,	校验集测试率: 2.06%
# 第 16700 (epoch: 19.43) 步:	 训练测试率: 3.12%,	校验集测试率: 2.26%
# 第 16800 (epoch: 19.55) 步:	 训练测试率: 6.25%,	校验集测试率: 1.96%
# 第 16900 (epoch: 19.67) 步:	 训练测试率: 3.12%,	校验集测试率: 2.16%
# 第 17000 (epoch: 19.78) 步:	 训练测试率: 4.69%,	校验集测试率: 2.12%
# 第 17100 (epoch: 19.90) 步:	 训练测试率: 1.56%,	校验集测试率: 2.12%
# 测试误差: 2.3%

# %%
plt.plot(error_rate_rec)
plt.xlabel('Batches')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
#将测试集喂进去，得到计算结果，看一看预测的准确度
right = 0
batch_num = len(test_data) // BATCH_SIZE
for i in range(batch_num):
    inputs = test_data[i * BATCH_SIZE : (i + 1) * BATCH_SIZE]
    inputs = torch.from_numpy(inputs)
    inputs = inputs.clone().detach()
    result = net(inputs)
    result = result.data.numpy()
    
    labels = test_labels[i * BATCH_SIZE : (i + 1) * BATCH_SIZE]
    right += np.sum(np.argmax(result, 1) == labels)
print(right / float(batch_num * BATCH_SIZE))
# Out:
# 0.9772636217948718
